# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import logging
import numpy as np

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def load_data(file_path):
    try:
        data = pd.read_csv(file_path)
        logging.info(f"Dataset {file_path} loaded successfully.")
        return data
    except Exception as e:
        logging.error(f"Error loading dataset {file_path}: {e}")
        return None

def preprocess_data(data):
    data = data.copy()

    # List of required columns
    required_columns = ['name', 'based_in', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 
                        'position', 'group', 'club', 'division', 'division_tier', 'second_nationality', 
                        'is_top_4_tier', 'age_(months)_on_1_july_2015', 'birth_month', 'birth_quarter',
                        'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'tier_quality']

    # Check if all required columns are present
    for col in required_columns:
        if col not in data.columns:
            logging.warning(f"Required column '{col}' not found in the dataset.")

    # Convert categorical variables to numerical using LabelEncoder
    label_encoders = {}
    categorical_columns = ['name', 'based_in', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 
                           'position', 'group', 'club', 'division', 'division_tier', 'second_nationality', 
                           'is_top_4_tier']

    for col in categorical_columns:
        if col in data.columns:
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col].astype(str))
            label_encoders[col] = le
        else:
            logging.warning(f"Column '{col}' not found in the dataset.")

    # Convert numerical columns to numeric
    numerical_columns = ['age_(months)_on_1_july_2015', 'birth_month', 'birth_quarter', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'tier_quality']
    for col in numerical_columns:
        if col in data.columns:
            data[col] = pd.to_numeric(data[col], errors='coerce')
            if data[col].isnull().any():
                logging.warning(f"Column '{col}' contains invalid entries that were converted to NaN.")
        else:
            logging.warning(f"Numerical column '{col}' not found in the dataset.")

    # Handle missing values - fill NaNs with a placeholder (e.g., -1) or the median for numerical columns
    data.fillna(-1, inplace=True)

    return data, label_encoders

def prepare_features_and_targets(data):
    feature_columns = ['position', 'group', 'age_(months)_on_1_july_2015', 'birth_month', 'birth_quarter', 'second_nationality', 'height_(cm)', 'weight_(kg)', 
                       'club', 'division', 'division_tier', 'tier_quality']
    target_columns = ['goals', 'appearances', 'tier_quality']
    
    # Check for missing columns and log a warning
    for col in feature_columns:
        if col not in data.columns:
            logging.warning(f"Feature column '{col}' not found in the dataset.")
    
    for col in target_columns:
        if col not in data.columns:
            logging.warning(f"Target column '{col}' not found in the dataset.")

    features = data[feature_columns]
    target_goals = data['goals'].astype(int)
    target_appearances = data['appearances'].astype(int)
    target_tier_quality = data['tier_quality']

    X = features
    y_goals = target_goals
    y_appearances = target_appearances
    y_tier_quality = target_tier_quality

    return X, y_goals, y_appearances, y_tier_quality


def tune_hyperparameters(X_train, y_train, is_classifier=False):
    param_distributions = {
        'n_estimators': np.arange(100, 1100, 100),
        'max_depth': [None] + list(np.arange(10, 51, 10)),
        'min_samples_split': [2, 5, 10, 15, 20],
        'min_samples_leaf': [1, 2, 5, 10]
    }
    
    if is_classifier:
        model = RandomForestClassifier(random_state=42)
        scoring = 'accuracy'
    else:
        model = RandomForestRegressor(random_state=42)
        scoring = 'neg_mean_squared_error'
    
    random_search = RandomizedSearchCV(estimator=model, param_distributions=param_distributions, 
                                       n_iter=100, cv=5, n_jobs=-1, verbose=2, scoring=scoring, random_state=42)
    
    random_search.fit(X_train, y_train)
    logging.info(f"Best parameters: {random_search.best_params_}")
    return random_search.best_estimator_

def train_and_evaluate(X_train, y_train_goals, y_train_appearances, y_train_tier_quality, X_val, y_val_goals, y_val_appearances, y_val_tier_quality):
    # Tune hyperparameters for goals prediction
    best_rf_goals = tune_hyperparameters(X_train, y_train_goals)
    best_rf_goals.fit(X_train, y_train_goals)

    # Tune hyperparameters for appearances prediction
    best_rf_appearances = tune_hyperparameters(X_train, y_train_appearances)
    best_rf_appearances.fit(X_train, y_train_appearances)

    # Tune hyperparameters for tier quality prediction
    best_rf_tier_quality = tune_hyperparameters(X_train, y_train_tier_quality, is_classifier=True)
    best_rf_tier_quality.fit(X_train, y_train_tier_quality)

    # Evaluate the models on validation set
    y_val_pred_goals = best_rf_goals.predict(X_val)
    y_val_pred_appearances = best_rf_appearances.predict(X_val)
    y_val_pred_tier_quality = best_rf_tier_quality.predict(X_val)

    logging.info(f'Validation MSE Goals: {mean_squared_error(y_val_goals, y_val_pred_goals):.0f}')
    logging.info(f'Validation MSE Appearances: {mean_squared_error(y_val_appearances, y_val_pred_appearances):.0f}')
    logging.info(f'Validation Accuracy Tier Quality: {accuracy_score(y_val_tier_quality, y_val_pred_tier_quality)}')

    return best_rf_goals, best_rf_appearances, best_rf_tier_quality

def evaluate_models(best_rf_goals, best_rf_appearances, best_rf_tier_quality, X_test, y_test_goals, y_test_appearances, y_test_tier_quality):
    # Make predictions on the testing set
    y_pred_goals = best_rf_goals.predict(X_test)
    y_pred_appearances = best_rf_appearances.predict(X_test)
    y_pred_tier_quality = best_rf_tier_quality.predict(X_test)

    # Evaluate the models
    mse_goals = mean_squared_error(y_test_goals, y_pred_goals)
    mse_appearances = mean_squared_error(y_test_appearances, y_pred_appearances)
    accuracy_tier_quality = accuracy_score(y_test_tier_quality, y_pred_tier_quality)

    logging.info(f'MSE Goals: {mse_goals:.0f}')
    logging.info(f'MSE Appearances: {mse_appearances:.0f}')
    logging.info(f'Accuracy Tier Quality: {accuracy_tier_quality}')

    # Convert feature importances to percentages
    feature_names = X_test.columns  # Get feature names
    goals_feature_importances = best_rf_goals.feature_importances_ * 100
    appearances_feature_importances = best_rf_appearances.feature_importances_ * 100
    tier_quality_feature_importances = best_rf_tier_quality.feature_importances_ * 100

    # Pair feature names with their importance percentages, formatted to 2 decimal places
    goals_importances_with_names = {name: f'{imp:.2f}' for name, imp in zip(feature_names, goals_feature_importances)}
    appearances_importances_with_names = {name: f'{imp:.2f}' for name, imp in zip(feature_names, appearances_feature_importances)}
    tier_quality_importances_with_names = {name: f'{imp:.2f}' for name, imp in zip(feature_names, tier_quality_feature_importances)}

    # Log the feature importances with names
    logging.info(f'Feature importances for goals (as percentages): {goals_importances_with_names}')
    logging.info(f'Feature importances for appearances (as percentages): {appearances_importances_with_names}')
    logging.info(f'Feature importances for tier quality (as percentages): {tier_quality_importances_with_names}')

    return y_pred_goals, y_pred_appearances, y_pred_tier_quality

def save_predictions(original_data, X_test, y_pred_goals, y_pred_appearances, y_pred_tier_quality, output_file):
    # Filter the original data to match the X_test indices
    filtered_original_data = original_data.loc[X_test.index]

    # Create predictions DataFrame
    predictions = pd.DataFrame({
        'name': filtered_original_data['name'],
        'position': filtered_original_data['position'],
        'group': filtered_original_data['group'],
        'date_of_birth': filtered_original_data['date_of_birth'],
        'birth_month': filtered_original_data['birth_month'],
        'birth_quarter': filtered_original_data['birth_quarter'],  
        'appearances_pred': np.round(y_pred_appearances, 0).astype(int),
        'goals_pred': np.round(y_pred_goals, 0).astype(int),
        'tier_pred': y_pred_tier_quality
    })
    
    # Save predictions to CSV
    predictions.to_csv(output_file, index=False)
    logging.info(f"Predictions have been saved to '{output_file}'.")

def main():
    # Load and preprocess the 2016 senior players dataset
    data_senior = load_data('dataset_2016_senior_players.csv')
    if data_senior is not None:
        logging.info(f"Columns in the senior dataset: {data_senior.columns.tolist()}")
        data_senior_preprocessed, _ = preprocess_data(data_senior)

        # Filter the data for players aged 23 or below (276 months or below) and not goalkeepers
        data_senior_preprocessed = data_senior_preprocessed[
            (data_senior_preprocessed['age_(months)_on_1_july_2015'] <= 276) &
            (data_senior_preprocessed['group'] != 2)  # Where '2' is the encoded value for goalkeepers
        ]

        X_senior, y_goals_senior, y_appearances_senior, y_tier_quality_senior = prepare_features_and_targets(data_senior_preprocessed)
        
        # Split the senior dataset into training and validation sets
        X_train_senior, X_val_senior, y_train_goals_senior, y_val_goals_senior, y_train_appearances_senior, y_val_appearances_senior, y_train_tier_quality_senior, y_val_tier_quality_senior = train_test_split(
            X_senior, y_goals_senior, y_appearances_senior, y_tier_quality_senior, test_size=0.2, random_state=42)
        
        # Log the distribution of target variables
        logging.info(f"Goals distribution in senior training set: {y_train_goals_senior.describe()}")
        logging.info(f"Appearances distribution in senior training set: {y_train_appearances_senior.describe()}")

        # Train the model on the senior dataset and evaluate on the validation set
        best_rf_goals, best_rf_appearances, best_rf_tier_quality = train_and_evaluate(
            X_train_senior, y_train_goals_senior, y_train_appearances_senior, y_train_tier_quality_senior,
            X_val_senior, y_val_goals_senior, y_val_appearances_senior, y_val_tier_quality_senior)

    # Load and preprocess the 2016 youth players dataset
    data_youth = load_data('dataset_2016_youth_players.csv')
    if data_youth is not None:
        logging.info(f"Columns in the youth dataset: {data_youth.columns.tolist()}")
        data_youth_preprocessed, _ = preprocess_data(data_youth)

        # Filter the data for not goalkeepers
        data_youth_preprocessed = data_youth_preprocessed[
            (data_youth_preprocessed['group'] != 2)  # Where '2' is the encoded value for goalkeepers
        ]

        X_test_youth, y_test_goals_youth, y_test_appearances_youth, y_test_tier_quality_youth = prepare_features_and_targets(data_youth_preprocessed)
        
        # Make predictions on the youth dataset using the models trained on the senior dataset
        y_pred_goals_youth, y_pred_appearances_youth, y_pred_tier_quality_youth = evaluate_models(
            best_rf_goals, best_rf_appearances, best_rf_tier_quality, X_test_youth, y_test_goals_youth, y_test_appearances_youth, y_test_tier_quality_youth)

        # Save predictions for the youth dataset
        save_predictions(data_youth, X_test_youth, y_pred_goals_youth, y_pred_appearances_youth, y_pred_tier_quality_youth, 'predictions_2016_youth.csv')

if __name__ == "__main__":
    main()
# Out:
# 2024-08-08 11:59:17,032 - INFO - Dataset dataset_2016_senior_players.csv loaded successfully.
# 2024-08-08 11:59:17,034 - INFO - Columns in the senior dataset: ['name', 'position', 'group', 'club', 'division', 'based_in', 'division_tier', 'tier_quality', 'date_of_birth', 'birth_month', 'birth_quarter', 'age_(days)_on_1_july_2015', 'age_(months)_on_1_july_2015', 'age_(years)_on_1_july_2015', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 'second_nationality', 'height_(ft_in)', 'height_(ft)', 'height_(in)', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'is_top_4_tier', 'train_or_test']
# 2024-08-08 11:59:17,063 - WARNING - Column 'tier_quality' contains invalid entries that were converted to NaN.
# 2024-08-08 11:59:17,093 - INFO - Goals distribution in senior training set: count    314.00000
# mean       3.05414
# std        7.24780
# min        0.00000
# 25%        0.00000
# 50%        1.00000
# 75%        3.00000
# max       65.00000
# Name: goals, dtype: float64
# 2024-08-08 11:59:17,094 - INFO - Appearances distribution in senior training set: count    314.000000
# mean      26.038217
# std       31.604259
# min        1.000000
# 25%        4.000000
# 50%       14.000000
# 75%       35.750000
# max      166.000000
# Name: appearances, dtype: float64
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   1.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   0.5s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   1.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   1.5s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   1.1s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   0.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   2.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   2.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   2.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   2.1s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.3s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.5s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.6s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.7s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# ...
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.0s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   1.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   1.9s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.3s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.9s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   0.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   0.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.4s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   0.4s
# 2024-08-08 12:02:20,710 - INFO - Best parameters: {'n_estimators': 1000, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_depth': 20}
# 2024-08-08 12:02:21,425 - INFO - Validation MSE Goals: 56
# 2024-08-08 12:02:21,425 - INFO - Validation MSE Appearances: 497
# 2024-08-08 12:02:21,426 - INFO - Validation Accuracy Tier Quality: 0.9746835443037974
# 2024-08-08 12:02:21,903 - INFO - Dataset dataset_2016_youth_players.csv loaded successfully.
# 2024-08-08 12:02:21,904 - INFO - Columns in the youth dataset: ['name', 'position', 'group', 'club', 'division', 'based_in', 'division_tier', 'tier_quality', 'date_of_birth', 'birth_month', 'birth_quarter', 'age_(days)_on_1_july_2015', 'age_(months)_on_1_july_2015', 'age_(years)_on_1_july_2015', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 'second_nationality', 'height_(ft_in)', 'height_(ft)', 'height_(in)', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'is_top_4_tier', 'train_or_test']
# 2024-08-08 12:02:22,078 - INFO - MSE Goals: 40
# 2024-08-08 12:02:22,079 - INFO - MSE Appearances: 588
# 2024-08-08 12:02:22,079 - INFO - Accuracy Tier Quality: 0.6331269349845201
# 2024-08-08 12:02:22,137 - INFO - Feature importances for goals (as percentages): {'position': '17.89', 'group': '0.41', 'age_(months)_on_1_july_2015': '54.85', 'birth_month': '5.93', 'birth_quarter': '0.38', 'second_nationality': '2.39', 'height_(cm)': '4.44', 'weight_(kg)': '8.19', 'club': '2.28', 'division': '0.69', 'division_tier': '2.22', 'tier_quality': '0.34'}
# 2024-08-08 12:02:22,137 - INFO - Feature importances for appearances (as percentages): {'position': '6.33', 'group': '1.13', 'age_(months)_on_1_july_2015': '57.29', 'birth_month': '6.55', 'birth_quarter': '4.39', 'second_nationality': '1.32', 'height_(cm)': '5.66', 'weight_(kg)': '2.90', 'club': '7.79', 'division': '1.51', 'division_tier': '4.27', 'tier_quality': '0.86'}
# 2024-08-08 12:02:22,138 - INFO - Feature importances for tier quality (as percentages): {'position': '0.58', 'group': '0.15', 'age_(months)_on_1_july_2015': '1.11', 'birth_month': '0.65', 'birth_quarter': '0.34', 'second_nationality': '0.42', 'height_(cm)': '0.65', 'weight_(kg)': '1.11', 'club': '3.26', 'division': '34.21', 'division_tier': '26.22', 'tier_quality': '31.30'}
# 2024-08-08 12:02:22,295 - INFO - Predictions have been saved to 'predictions_2016_youth.csv'.
