# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.model_selection import RandomizedSearchCV
import logging
import numpy as np

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def load_data(file_path):
    try:
        data = pd.read_csv(file_path)
        logging.info(f"Dataset {file_path} loaded successfully.")
        return data
    except Exception as e:
        logging.error(f"Error loading dataset {file_path}: {e}")
        return None

def preprocess_data(data):
    data = data.copy()

    # Convert categorical variables to numerical using LabelEncoder
    label_encoders = {}
    categorical_columns = ['name', 'based_in', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 
                           'position', 'group', 'club', 'division', 'division_tier', 'second_nationality', 
                           'is_top_4_tier']

    for col in categorical_columns:
        if col in data.columns:
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col].astype(str))
            label_encoders[col] = le
        else:
            logging.warning(f"Column '{col}' not found in the dataset.")

    # Handle missing values - fill NaNs with a placeholder (e.g., -1) or the median for numerical columns
    data.fillna(-1, inplace=True)

    return data

def prepare_features_and_targets(data):
    features = data[['name', 'position', 'group', 'age_(months)_on_1_july_2023', 'second_nationality', 'height_(cm)', 'weight_(kg)', 
                     'goals', 'appearances', 'club', 'division', 'division_tier', 'is_top_4_tier']]
    target_goals = data['goals'].astype(int)
    target_appearances = data['appearances'].astype(int)
    target_tier_quality = data['tier_quality']

    X = features
    y_goals = target_goals
    y_appearances = target_appearances
    y_tier_quality = target_tier_quality

    return X, y_goals, y_appearances, y_tier_quality

def tune_hyperparameters(X_train, y_train, is_classifier=False):
    param_distributions = {
        'n_estimators': np.arange(100, 1100, 100),
        'max_depth': [None] + list(np.arange(10, 51, 10)),
        'min_samples_split': [2, 5, 10, 15, 20],
        'min_samples_leaf': [1, 2, 5, 10]
    }
    
    if is_classifier:
        model = RandomForestClassifier(random_state=42)
        scoring = 'accuracy'
    else:
        model = RandomForestRegressor(random_state=42)
        scoring = 'neg_mean_squared_error'
    
    random_search = RandomizedSearchCV(estimator=model, param_distributions=param_distributions, 
                                       n_iter=100, cv=5, n_jobs=-1, verbose=2, scoring=scoring, random_state=42)
    
    random_search.fit(X_train, y_train)
    logging.info(f"Best parameters: {random_search.best_params_}")
    return random_search.best_estimator_

def train_and_evaluate(X_train, y_train_goals, y_train_appearances, y_train_tier_quality):
    # Tune hyperparameters for goals prediction
    best_rf_goals = tune_hyperparameters(X_train, y_train_goals)
    best_rf_goals.fit(X_train, y_train_goals)

    # Tune hyperparameters for appearances prediction
    best_rf_appearances = tune_hyperparameters(X_train, y_train_appearances)
    best_rf_appearances.fit(X_train, y_train_appearances)

    # Tune hyperparameters for tier quality prediction
    best_rf_tier_quality = tune_hyperparameters(X_train, y_train_tier_quality, is_classifier=True)
    best_rf_tier_quality.fit(X_train, y_train_tier_quality)

    # Evaluate the models
    y_train_pred_goals = best_rf_goals.predict(X_train)
    y_train_pred_appearances = best_rf_appearances.predict(X_train)
    y_train_pred_tier_quality = best_rf_tier_quality.predict(X_train)

    logging.info(f'Training MSE Goals: {mean_squared_error(y_train_goals, y_train_pred_goals)}')
    logging.info(f'Training MSE Appearances: {mean_squared_error(y_train_appearances, y_train_pred_appearances)}')
    logging.info(f'Training Accuracy Tier Quality: {accuracy_score(y_train_tier_quality, y_train_pred_tier_quality)}')

    return best_rf_goals, best_rf_appearances, best_rf_tier_quality

def evaluate_models(best_rf_goals, best_rf_appearances, best_rf_tier_quality, X_test, y_test_goals, y_test_appearances, y_test_tier_quality):
    # Make predictions on the testing set
    y_pred_goals = best_rf_goals.predict(X_test)
    y_pred_appearances = best_rf_appearances.predict(X_test)
    y_pred_tier_quality = best_rf_tier_quality.predict(X_test)

    # Evaluate the models
    mse_goals = mean_squared_error(y_test_goals, y_pred_goals)
    mse_appearances = mean_squared_error(y_test_appearances, y_pred_appearances)
    accuracy_tier_quality = accuracy_score(y_test_tier_quality, y_pred_tier_quality)

    logging.info(f'MSE Goals: {mse_goals}')
    logging.info(f'MSE Appearances: {mse_appearances}')
    logging.info(f'Accuracy Tier Quality: {accuracy_tier_quality}')

    # Check feature importance
    logging.info(f'Feature importances for goals: {best_rf_goals.feature_importances_}')
    logging.info(f'Feature importances for appearances: {best_rf_appearances.feature_importances_}')
    logging.info(f'Feature importances for tier quality: {best_rf_tier_quality.feature_importances_}')

    return y_pred_goals, y_pred_appearances, y_pred_tier_quality

def save_predictions(X_test, y_pred_goals, y_pred_appearances, y_pred_tier_quality, output_file):
    predictions = pd.DataFrame({
        'Player name': X_test['name'],
        'Position': X_test['position'],
        'Group': X_test['group'],
        'Predicted appearances': y_pred_appearances,
        'Predicted goals': y_pred_goals,
        'Predicted tier quality': y_pred_tier_quality
    })
    predictions.to_csv(output_file, index=False)
    logging.info(f"Predictions have been saved to '{output_file}'.")

def main():
    # Load and preprocess the senior players dataset
    data_senior = load_data('dataset_senior_players.csv')
    if data_senior is not None:
        logging.info(f"Columns in the senior dataset: {data_senior.columns.tolist()}")
        data_senior_preprocessed = preprocess_data(data_senior)
        X_train_senior, y_train_goals_senior, y_train_appearances_senior, y_train_tier_quality_senior = prepare_features_and_targets(data_senior_preprocessed)
        
        # Log the distribution of target variables
        logging.info(f"Goals distribution in senior training set: {y_train_goals_senior.describe()}")
        logging.info(f"Appearances distribution in senior training set: {y_train_appearances_senior.describe()}")

        # Train the model on the senior dataset
        best_rf_goals, best_rf_appearances, best_rf_tier_quality = train_and_evaluate(X_train_senior, y_train_goals_senior, y_train_appearances_senior, y_train_tier_quality_senior)

    # Load and preprocess the youth players dataset
    data_youth = load_data('dataset_youth_players.csv')
    if data_youth is not None:
        logging.info(f"Columns in the youth dataset: {data_youth.columns.tolist()}")
        data_youth_preprocessed = preprocess_data(data_youth)
        X_test_youth, y_test_goals_youth, y_test_appearances_youth, y_test_tier_quality_youth = prepare_features_and_targets(data_youth_preprocessed)
        
        # Make predictions on the youth dataset using the models trained on the senior dataset
        y_pred_goals_youth, y_pred_appearances_youth, y_pred_tier_quality_youth = evaluate_models(best_rf_goals, best_rf_appearances, best_rf_tier_quality, X_test_youth, y_test_goals_youth, y_test_appearances_youth, y_test_tier_quality_youth)

        # Save predictions for the youth dataset
        save_predictions(X_test_youth, y_pred_goals_youth, y_pred_appearances_youth, y_pred_tier_quality_youth, 'predictions_youth.csv')

if __name__ == "__main__":
    main()
# Out:
# 2024-07-14 15:32:28,658 - INFO - Dataset dataset_senior_players.csv loaded successfully.
# 2024-07-14 15:32:28,660 - INFO - Columns in the senior dataset: ['name', 'position', 'group', 'club', 'division', 'based_in', 'division_tier', 'tier_quality', 'date_of_birth', 'birth_month', 'birth_quarter', 'age_(days)_on_1_july_2023', 'age_(months)_on_1_july_2023', 'age_(years)_on_1_july_2023', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 'second_nationality', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'is_top_4_tier']
# 2024-07-14 15:32:28,681 - INFO - Goals distribution in senior training set: count    2141.000000
# mean       19.854741
# std        31.739549
# min         0.000000
# 25%         2.000000
# 50%         8.000000
# 75%        23.000000
# max       287.000000
# Name: goals, dtype: float64
# 2024-07-14 15:32:28,683 - INFO - Appearances distribution in senior training set: count    2141.000000
# mean      178.279776
# std       138.602443
# min        20.000000
# 25%        65.000000
# 50%       139.000000
# 75%       260.000000
# max       794.000000
# Name: appearances, dtype: float64
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.2s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   5.2s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   5.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   5.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   5.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   5.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   5.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   5.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   8.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   8.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   8.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   7.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   7.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=   7.4s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   6.5s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.1s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   4.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=   5.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   2.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   2.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   2.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   5.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.9s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.6s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   3.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   2.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   3.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.7s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   6.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   6.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   6.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   6.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   5.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   4.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   4.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   4.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   7.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=   6.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   2.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   3.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=   4.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   5.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   5.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   5.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.9s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   4.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   5.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   5.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   4.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=   4.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   5.3s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   2.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   2.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   2.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   2.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   2.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   2.8s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   5.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   5.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   4.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   5.0s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   4.9s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   5.0s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=   4.5s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   5.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   5.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   6.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   2.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=   5.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   1.8s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.0s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.2s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.6s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   5.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=   5.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   4.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   6.2s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   6.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   6.5s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   5.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=   5.9s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   2.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   2.3s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   4.7s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   4.7s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   4.7s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   4.9s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.4s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=   4.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.5s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   4.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   4.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   5.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   4.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=   4.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   3.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   4.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   3.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   1.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   1.9s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   1.6s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   1.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   5.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   4.9s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   5.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   5.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=   5.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   4.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   4.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   4.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   5.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=   4.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   3.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   5.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   4.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   4.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   4.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   4.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   5.3s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   5.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   5.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   5.4s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=   5.0s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   2.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   5.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   5.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   5.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   6.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=   5.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   5.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   6.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   1.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   5.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   6.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   5.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   5.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   3.0s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   2.0s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.7s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.7s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.1s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   4.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   1.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   2.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.7s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.6s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   5.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   5.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   5.6s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   5.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   5.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.6s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   2.1s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.2s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   2.4s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   2.2s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   3.1s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   3.1s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   5.9s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   6.3s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   2.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   4.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   4.5s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   2.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   4.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.5s
# ...
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.4s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   1.6s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.2s[CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.2s
#
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.9s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=   2.3s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   0.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=   2.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   2.9s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.0s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.3s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.5s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=   1.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.9s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   1.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=300; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=600; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   2.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   2.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=   2.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.3s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   3.1s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   2.3s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   3.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   2.6s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   2.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   3.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=800; total time=   3.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=15, n_estimators=500; total time=   2.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   1.0s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.0s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.1s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   1.1s
# 2024-07-14 15:42:23,415 - INFO - Best parameters: {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 30}
# 2024-07-14 15:42:25,533 - INFO - Training MSE Goals: 0.4567729051104609
# 2024-07-14 15:42:25,534 - INFO - Training MSE Appearances: 0.985930558150397
# 2024-07-14 15:42:25,535 - INFO - Training Accuracy Tier Quality: 1.0
# 2024-07-14 15:42:26,118 - INFO - Dataset dataset_youth_players.csv loaded successfully.
# 2024-07-14 15:42:26,119 - INFO - Columns in the youth dataset: ['name', 'position', 'group', 'club', 'division', 'based_in', 'division_tier', 'tier_quality', 'date_of_birth', 'birth_month', 'birth_quarter', 'age_(days)_on_1_july_2023', 'age_(months)_on_1_july_2023', 'age_(years)_on_1_july_2023', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 'second_nationality', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'is_top_4_tier']
# 2024-07-14 15:42:26,253 - INFO - MSE Goals: 0.0
# 2024-07-14 15:42:26,253 - INFO - MSE Appearances: 400.0
# 2024-07-14 15:42:26,253 - INFO - Accuracy Tier Quality: 0.31254752851711026
# 2024-07-14 15:42:26,259 - INFO - Feature importances for goals: [1.62318698e-05 7.10731864e-06 5.11437217e-07 2.08795256e-05
#  2.67205349e-05 7.65298558e-05 1.07552984e-04 9.99053993e-01
#  4.33597709e-04 1.80964957e-04 2.13113891e-05 4.93967567e-05
#  5.20313261e-06]
# 2024-07-14 15:42:26,264 - INFO - Feature importances for appearances: [1.62928630e-05 8.15781358e-06 1.03484968e-05 2.86505982e-05
#  1.90725730e-05 1.25944042e-05 6.79918513e-06 2.21044432e-05
#  9.99837698e-01 2.41768171e-05 3.82722507e-06 9.12726949e-06
#  1.15012417e-06]
# 2024-07-14 15:42:26,285 - INFO - Feature importances for tier quality: [0.00884837 0.007289   0.00199233 0.01071756 0.00858562 0.00450725
#  0.0068571  0.00727403 0.00956805 0.08111324 0.33711704 0.31166333
#  0.20446708]
# 2024-07-14 15:42:26,342 - INFO - Predictions have been saved to 'predictions_youth.csv'.
