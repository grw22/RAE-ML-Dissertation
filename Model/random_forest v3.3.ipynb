# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import logging
import numpy as np

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Read the dataset from the specified file path and log success or error
def load_data(file_path):
    try:
        data = pd.read_csv(file_path)
        logging.info(f"Dataset {file_path} loaded successfully.")
        return data
    except Exception as e:
        logging.error(f"Error loading dataset {file_path}: {e}")
        return None

# Copy the original data, drop unnecessary columns, apply One-Hot Encoding, align columns, apply label encoding, handle missing values, and return the modified dataset
def preprocess_data(data, age_column_name, all_columns=None):
    # Create a copy of the data to avoid modifying the original dataframe
    data = data.copy()

    # Drop unnecessary columns that are not required for the analysis
    data = data.drop(columns=['position', 'based_in', 'birth_region', 'nationality'])

    # Define nominal categorical columns that will be one-hot encoded
    nominal_columns = ['nation_of_birth', 'group', 'second_nationality', 'club', 'birth_city']
    
    # Apply One-Hot Encoding to nominal categorical variables
    data = pd.get_dummies(data, columns=nominal_columns)

    # Log the new columns after one-hot encoding for reference
    logging.info(f"Columns after one-hot encoding: {data.columns.tolist()}")

    # If all_columns is provided, ensure the dataset includes all specified columns
    if all_columns is not None:
        # Add missing columns with a default value of 0 to maintain consistency
        for col in all_columns:
            if col not in data.columns:
                data[col] = 0
        # Reorder columns to match the order in all_columns
        data = data[all_columns]

    # Initialise a dictionary to store label encoders for ordinal and binary columns
    label_encoders = {}

    # Define ordinal or binary categorical columns that will be label encoded
    ordinal_columns = ['division', 'division_tier', 'is_top_4_tier']

    # Apply Label Encoding to ordinal or binary categorical variables
    for col in ordinal_columns:
        if col in data.columns:
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col].astype(str))
            label_encoders[col] = le  # Store the encoder for potential inverse transformations

    # Handle missing values by filling NaNs with a placeholder value (e.g., -1)
    data.fillna(-1, inplace=True)

    # Return the preprocessed data along with the label encoders used
    return data, label_encoders


# Filter goalkeepers out of the dataset as they are not relevant to this particular investigation
def filter_goalkeepers(data):
    # Filter out goalkeepers using the correct column name
    if 'group_Goalkeeper' in data.columns:
        logging.info(f"Before filtering, data shape: {data.shape}")
        data = data[data['group_Goalkeeper'] != 1]  # Exclude rows where group_Goalkeeper is 1 (indicating goalkeepers)
        logging.info(f"After filtering goalkeepers, data shape: {data.shape}")
    else:
        logging.warning("Goalkeeper identification column 'group_Goalkeeper' not found. Check the encoding step.")
    return data

# Drop the columns that won't be used in the model and extract the target variables
def prepare_features_and_targets(data, age_column_name):
    # Drop the columns that should not be included in the model's features
    features = data.drop(columns=['goals', 'appearances', 'tier_quality', 'name', 'date_of_birth'])

    # Extract the target variables, converting to appropriate data types
    target_goals = data['goals'].astype(int)
    target_appearances = data['appearances'].astype(int)
    target_tier_quality = data['tier_quality']

    # Assign the features to X and the target variables to separate y variables
    X = features
    y_goals = target_goals
    y_appearances = target_appearances
    y_tier_quality = target_tier_quality

    # Return the features and the target variables
    return X, y_goals, y_appearances, y_tier_quality


# Set the hyperparameters based on what returns the best results through testing different parameters and RandomizedSearchCV
def tune_hyperparameters(X_train, y_train, is_classifier=False):
    # Define the distribution of hyperparameters to search over
    param_distributions = {
        'n_estimators': np.arange(100, 1100, 100),  # Explore a wide range of trees from 100 to 1000
        'max_depth': [None] + list(np.arange(10, 51, 10)),  # Test various depths, including unrestricted growth (None)
        'min_samples_split': [2, 5, 10, 15, 20],  # Experiment with different split criteria to control overfitting
        'min_samples_leaf': [1, 2, 5, 10]  # Adjust leaf size to balance complexity and generalisation
    }
    
    # Choose the model and scoring metric based on whether it is a classifier (output is a category or class) or regressor (output is a continuous value)
    if is_classifier:
        model = RandomForestClassifier(random_state=42)
        scoring = 'accuracy'  # Use accuracy as the scoring metric for classification
    else:
        model = RandomForestRegressor(random_state=42)
        scoring = 'neg_mean_squared_error'  # Use negative mean squared error for regression
    
    # Set up the RandomizedSearchCV to find the best hyperparameters across the defined search space
    random_search = RandomizedSearchCV(estimator=model, param_distributions=param_distributions, 
                                       n_iter=100, cv=5, n_jobs=-1, verbose=2, scoring=scoring, random_state=42)
    
    # Fit the model to the training data while tuning hyperparameters
    random_search.fit(X_train, y_train)
    
    # Log the best hyperparameters found during the search
    logging.info(f"Best parameters: {random_search.best_params_}")
    
    # Return the model with the best-found hyperparameters
    return random_search.best_estimator_


# Tune hyperparameters, train, evaluate the RandomForest models and log their performance metrics
def train_and_evaluate(X_train, y_train_goals, y_train_appearances, y_train_tier_quality, X_val, y_val_goals, y_val_appearances, y_val_tier_quality):
    # Tune hyperparameters for goals prediction
    best_rf_goals = tune_hyperparameters(X_train, y_train_goals)
    best_rf_goals.fit(X_train, y_train_goals)

    # Tune hyperparameters for appearances prediction
    best_rf_appearances = tune_hyperparameters(X_train, y_train_appearances)
    best_rf_appearances.fit(X_train, y_train_appearances)

    # Tune hyperparameters for tier quality prediction
    best_rf_tier_quality = tune_hyperparameters(X_train, y_train_tier_quality, is_classifier=True)
    best_rf_tier_quality.fit(X_train, y_train_tier_quality)

    # Evaluate the models on validation set
    y_val_pred_goals = best_rf_goals.predict(X_val)
    y_val_pred_appearances = best_rf_appearances.predict(X_val)
    y_val_pred_tier_quality = best_rf_tier_quality.predict(X_val)

    logging.info(f'Validation MSE Goals: {mean_squared_error(y_val_goals, y_val_pred_goals):.0f}')
    logging.info(f'Validation MSE Appearances: {mean_squared_error(y_val_appearances, y_val_pred_appearances):.0f}')
    logging.info(f'Validation Accuracy Tier Quality: {accuracy_score(y_val_tier_quality, y_val_pred_tier_quality)}')
    logging.info(f'Validation Classification Report Tier Quality:\n{classification_report(y_val_tier_quality, y_val_pred_tier_quality)}')

    return best_rf_goals, best_rf_appearances, best_rf_tier_quality


# Evaluate the trained RF model and log the metrics and feature importance
def evaluate_models(best_rf_goals, best_rf_appearances, best_rf_tier_quality, X_test, y_test_goals, y_test_appearances, y_test_tier_quality):
    # Make predictions on the testing set
    y_pred_goals = best_rf_goals.predict(X_test)
    y_pred_appearances = best_rf_appearances.predict(X_test)
    y_pred_tier_quality = best_rf_tier_quality.predict(X_test)

    # Evaluate the models
    mse_goals = mean_squared_error(y_test_goals, y_pred_goals)
    mse_appearances = mean_squared_error(y_test_appearances, y_pred_appearances)
    accuracy_tier_quality = accuracy_score(y_test_tier_quality, y_pred_tier_quality)

    logging.info(f'MSE Goals: {mse_goals:.0f}')
    logging.info(f'MSE Appearances: {mse_appearances:.0f}')
    logging.info(f'Accuracy Tier Quality: {accuracy_tier_quality}')
    logging.info(f'Test Classification Report Tier Quality:\n{classification_report(y_test_tier_quality, y_pred_tier_quality)}')

    # Convert feature importances to percentages
    feature_names = X_test.columns  # Get feature names
    goals_feature_importances = best_rf_goals.feature_importances_ * 100
    appearances_feature_importances = best_rf_appearances.feature_importances_ * 100
    tier_quality_feature_importances = best_rf_tier_quality.feature_importances_ * 100

    # Pair feature names with their importance percentages, formatted to 2 decimal places
    goals_importances_with_names = {name: f'{imp:.2f}' for name, imp in zip(feature_names, goals_feature_importances)}
    appearances_importances_with_names = {name: f'{imp:.2f}' for name, imp in zip(feature_names, appearances_feature_importances)}
    tier_quality_importances_with_names = {name: f'{imp:.2f}' for name, imp in zip(feature_names, tier_quality_feature_importances)}

    # Log the feature importances with names
    logging.info(f'Feature importances for goals (as percentages): {goals_importances_with_names}')
    logging.info(f'Feature importances for appearances (as percentages): {appearances_importances_with_names}')
    logging.info(f'Feature importances for tier quality (as percentages): {tier_quality_importances_with_names}')

    return y_pred_goals, y_pred_appearances, y_pred_tier_quality


# Save the predictions by filtering the original data to match the test set and out put to a CSV file
def save_predictions(original_data, X_test, y_pred_goals, y_pred_appearances, y_pred_tier_quality, output_file):
    # Filter the original data to match the X_test indices
    filtered_original_data = original_data.loc[X_test.index]

    # Reconstruct the 'group' column if necessary
    group_columns = [col for col in filtered_original_data.columns if col.startswith('group_')]
    if group_columns:
        filtered_original_data['group'] = filtered_original_data[group_columns].idxmax(axis=1).str.replace('group_', '')

    # Create predictions DataFrame
    predictions = pd.DataFrame({
        'name': filtered_original_data['name'],
        'position': filtered_original_data['position'],
        'group': filtered_original_data['group'],
        'date_of_birth': filtered_original_data['date_of_birth'],
        'birth_month': filtered_original_data['birth_month'],
        'birth_quarter': filtered_original_data['birth_quarter'],  
        'appearances_pred': np.round(y_pred_appearances, 0).astype(int),
        'goals_pred': np.round(y_pred_goals, 0).astype(int),
        'tier_pred': y_pred_tier_quality
    })
    
    # Save predictions to CSV
    predictions.to_csv(output_file, index=False)
    logging.info(f"Predictions have been saved to '{output_file}'.")

def main():
    # Load and preprocess the 2016 senior players dataset
    data_senior_2016 = load_data('dataset_2016_senior_players.csv')
    if data_senior_2016 is not None:
        logging.info(f"Columns in the 2016 senior dataset: {data_senior_2016.columns.tolist()}")
        data_senior_preprocessed_2016, _ = preprocess_data(data_senior_2016, 'age_(months)_on_1_july_2015')
        
        # Filter out goalkeepers after preprocessing
        data_senior_preprocessed_2016 = filter_goalkeepers(data_senior_preprocessed_2016)

        # Capture all column names after preprocessing the training data
        all_columns_2016 = data_senior_preprocessed_2016.columns.tolist()

        # Prepare features and targets for the senior dataset (training)
        X_senior_2016, y_goals_senior_2016, y_appearances_senior_2016, y_tier_quality_senior_2016 = prepare_features_and_targets(data_senior_preprocessed_2016, 'age_(months)_on_1_july_2015')
        
        # Split the senior dataset into training and validation sets
        X_train_senior_2016, X_val_senior_2016, y_train_goals_senior_2016, y_val_goals_senior_2016, y_train_appearances_senior_2016, y_val_appearances_senior_2016, y_train_tier_quality_senior_2016, y_val_tier_quality_senior_2016 = train_test_split(
            X_senior_2016, y_goals_senior_2016, y_appearances_senior_2016, y_tier_quality_senior_2016, test_size=0.2, random_state=42)
        
        # Train the models on the senior dataset and evaluate on the validation set
        best_rf_goals_2016, best_rf_appearances_2016, best_rf_tier_quality_2016 = train_and_evaluate(
            X_train_senior_2016, y_train_goals_senior_2016, y_train_appearances_senior_2016, y_train_tier_quality_senior_2016,
            X_val_senior_2016, y_val_goals_senior_2016, y_val_appearances_senior_2016, y_val_tier_quality_senior_2016)

    # Load and preprocess the 2016 youth players dataset
    data_youth_2016 = load_data('dataset_2016_youth_players.csv')
    if data_youth_2016 is not None:
        logging.info(f"Columns in the 2016 youth dataset: {data_youth_2016.columns.tolist()}")
        data_youth_preprocessed_2016, _ = preprocess_data(data_youth_2016, 'age_(months)_on_1_july_2015', all_columns=all_columns_2016)

        # Filter out goalkeepers after preprocessing
        data_youth_preprocessed_2016 = filter_goalkeepers(data_youth_preprocessed_2016)

        # Prepare features and targets for the youth dataset (testing)
        X_test_youth_2016, y_test_goals_youth_2016, y_test_appearances_youth_2016, y_test_tier_quality_youth_2016 = prepare_features_and_targets(data_youth_preprocessed_2016, 'age_(months)_on_1_july_2015')
        
        # Make predictions on the youth dataset using the models trained on the senior dataset
        y_pred_goals_youth_2016, y_pred_appearances_youth_2016, y_pred_tier_quality_youth_2016 = evaluate_models(
            best_rf_goals_2016, best_rf_appearances_2016, best_rf_tier_quality_2016, X_test_youth_2016, y_test_goals_youth_2016, y_test_appearances_youth_2016, y_test_tier_quality_youth_2016)

        # Save predictions for the 2016 youth dataset
        save_predictions(data_youth_2016, X_test_youth_2016, y_pred_goals_youth_2016, y_pred_appearances_youth_2016, y_pred_tier_quality_youth_2016, 'predictions_2016_youth.csv')

    # Repeat the same process for the 2024 datasets

    data_senior_2024 = load_data('dataset_2024_senior_players.csv')
    if data_senior_2024 is not None:
        logging.info(f"Columns in the 2024 senior dataset: {data_senior_2024.columns.tolist()}")
        data_senior_preprocessed_2024, _ = preprocess_data(data_senior_2024, 'age_(months)_on_1_july_2023')
        
        # Filter out goalkeepers after preprocessing
        data_senior_preprocessed_2024 = filter_goalkeepers(data_senior_preprocessed_2024)

        # Capture all column names after preprocessing the training data
        all_columns_2024 = data_senior_preprocessed_2024.columns.tolist()

        # Prepare features and targets for the senior dataset (training)
        X_senior_2024, y_goals_senior_2024, y_appearances_senior_2024, y_tier_quality_senior_2024 = prepare_features_and_targets(data_senior_preprocessed_2024, 'age_(months)_on_1_july_2023')
        
        # Split the senior dataset into training and validation sets
        X_train_senior_2024, X_val_senior_2024, y_train_goals_senior_2024, y_val_goals_senior_2024, y_train_appearances_senior_2024, y_val_appearances_senior_2024, y_train_tier_quality_senior_2024, y_val_tier_quality_senior_2024 = train_test_split(
            X_senior_2024, y_goals_senior_2024, y_appearances_senior_2024, y_tier_quality_senior_2024, test_size=0.2, random_state=42)
        
        # Train the models on the senior dataset and evaluate on the validation set
        best_rf_goals_2024, best_rf_appearances_2024, best_rf_tier_quality_2024 = train_and_evaluate(
            X_train_senior_2024, y_train_goals_senior_2024, y_train_appearances_senior_2024, y_train_tier_quality_senior_2024,
            X_val_senior_2024, y_val_goals_senior_2024, y_val_appearances_senior_2024, y_val_tier_quality_senior_2024)

    data_youth_2024 = load_data('dataset_2024_youth_players.csv')
    if data_youth_2024 is not None:
        logging.info(f"Columns in the 2024 youth dataset: {data_youth_2024.columns.tolist()}")
        data_youth_preprocessed_2024, _ = preprocess_data(data_youth_2024, 'age_(months)_on_1_july_2023', all_columns=all_columns_2024)

        # Filter out goalkeepers after preprocessing
        data_youth_preprocessed_2024 = filter_goalkeepers(data_youth_preprocessed_2024)

        # Prepare features and targets for the youth dataset (testing)
        X_test_youth_2024, y_test_goals_youth_2024, y_test_appearances_youth_2024, y_test_tier_quality_youth_2024 = prepare_features_and_targets(data_youth_preprocessed_2024, 'age_(months)_on_1_july_2023')
        
        # Make predictions on the youth dataset using the models trained on the senior dataset
        y_pred_goals_youth_2024, y_pred_appearances_youth_2024, y_pred_tier_quality_youth_2024 = evaluate_models(
            best_rf_goals_2024, best_rf_appearances_2024, best_rf_tier_quality_2024, X_test_youth_2024, y_test_goals_youth_2024, y_test_appearances_youth_2024, y_test_tier_quality_youth_2024)

        # Save predictions for the 2024 youth dataset
        save_predictions(data_youth_2024, X_test_youth_2024, y_pred_goals_youth_2024, y_pred_appearances_youth_2024, y_pred_tier_quality_youth_2024, 'predictions_2024_youth.csv')

if __name__ == "__main__":
    main()
# Out:
# 2024-08-15 12:53:06,300 - INFO - Dataset dataset_2016_senior_players.csv loaded successfully.
# 2024-08-15 12:53:06,301 - INFO - Columns in the 2016 senior dataset: ['name', 'position', 'group', 'club', 'division', 'based_in', 'division_tier', 'tier_quality', 'date_of_birth', 'birth_month', 'birth_quarter', 'age_(days)_on_1_july_2015', 'age_(months)_on_1_july_2015', 'age_(years)_on_1_july_2015', 'birth_city', 'nation_of_birth', 'birth_region', 'nationality', 'second_nationality', 'height_(ft_in)', 'height_(ft)', 'height_(in)', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'is_top_4_tier', 'train_or_test']
# 2024-08-15 12:53:06,321 - INFO - Columns after one-hot encoding: ['name', 'division', 'division_tier', 'tier_quality', 'date_of_birth', 'birth_month', 'birth_quarter', 'age_(days)_on_1_july_2015', 'age_(months)_on_1_july_2015', 'age_(years)_on_1_july_2015', 'height_(ft_in)', 'height_(ft)', 'height_(in)', 'height_(cm)', 'weight_(kg)', 'goals', 'appearances', 'is_top_4_tier', 'train_or_test', 'nation_of_birth_ENG', 'group_Defender', 'group_Forward', 'group_Goalkeeper', 'group_Midfielder', 'second_nationality_ALB', 'second_nationality_ANG', 'second_nationality_ASA', 'second_nationality_ATG', 'second_nationality_AUS', 'second_nationality_AUT', 'second_nationality_BDI', 'second_nationality_BEL', 'second_nationality_BRB', 'second_nationality_CAN', 'second_nationality_CGO', 'second_nationality_CHN', 'second_nationality_CIV', 'second_nationality_CMR', 'second_nationality_COD', 'second_nationality_COL', 'second_nationality_CYP', 'second_nationality_DEN', 'second_nationality_DMA', 'second_nationality_EGY', 'second_nationality_ESP', 'second_nationality_FIN', 'second_nationality_FRA', 'second_nationality_GAM', 'second_nationality_GER', 'second_nationality_GHA', 'second_nationality_GRN', 'second_nationality_GUY', 'second_nationality_HUN', 'second_nationality_IND', 'second_nationality_IRL', 'second_nationality_IRN', 'second_nationality_IRQ', 'second_nationality_ISR', 'second_nationality_ITA', 'second_nationality_JAM', 'second_nationality_LBR', 'second_nationality_LCA', 'second_nationality_LVA', 'second_nationality_MLT', 'second_nationality_MSR', 'second_nationality_MWI', 'second_nationality_NCL', 'second_nationality_NED', 'second_nationality_NGA', 'second_nationality_NIR', 'second_nationality_NZL', 'second_nationality_PAK', 'second_nationality_PHI', 'second_nationality_POL', 'second_nationality_POR', 'second_nationality_RSA', 'second_nationality_RUS', 'second_nationality_SCO', 'second_nationality_SEY', 'second_nationality_SIN', 'second_nationality_SKN', 'second_nationality_SLE', 'second_nationality_SOM', 'second_nationality_SRB', 'second_nationality_TPE', 'second_nationality_TRI', 'second_nationality_TUR', 'second_nationality_UGA', 'second_nationality_USA', 'second_nationality_VEN', 'second_nationality_WAL', 'second_nationality_ZIM', 'club_AFC Liverpool', 'club_AFC Sudbury', 'club_AFC Telford', 'club_AFC United', 'club_AFC Wimbledon', 'club_AIK', 'club_Aberdeen', 'club_Accrington', 'club_Airdrie', 'club_Aldershot', 'club_Alfreton', 'club_Alloa', 'club_Altrincham', 'club_Amesbury', 'club_Annan', 'club_Arbroath', 'club_Arsenal', 'club_Ashton Utd', 'club_Aston Villa', 'club_Atlanta Silverbacks', 'club_Bamber Bridge', 'club_Bangor City', 'club_Barnet', 'club_Barnsley', 'club_Barrow', 'club_Basildon', 'club_Belper', 'club_Bentleigh Greens', 'club_Berliner AK', 'club_Berwick', 'club_Bharat FC', 'club_Biggleswade Town', 'club_Birmingham', 'club_Blackburn', 'club_Blackpool', 'club_Blyth', 'club_Bolton', 'club_Boreham Wood', 'club_Bournemouth', 'club_Bradford City', 'club_Braintree', 'club_Brechin', 'club_Brentford', 'club_Brentwood', 'club_Brighton', 'club_Bristol City', 'club_Bristol Rovers', 'club_Bromley', 'club_Burnley', 'club_Burton', 'club_Bury', 'club_Buxton', 'club_Cambridge', 'club_Cardiff', 'club_Carlisle', 'club_Carolina RailHawks', 'club_Celtic', 'club_Central Coast Mariners', 'club_Chania', 'club_Charlton', 'club_Chelsea', 'club_Cheltenham', 'club_Chester', 'club_Chesterfield', 'club_Chicago', 'club_Cirencester', 'club_Colchester', 'club_Colwyn Bay', "club_Connah's Quay", 'club_Corby', 'club_Coventry', 'club_Crawley', 'club_Crewe', 'club_Crystal Palace', 'club_Dag & Red', 'club_Derby', 'club_Doncaster', 'club_Dover', 'club_Dumbarton', 'club_Dundee', 'club_Dundee Utd', 'club_Dunfermline', 'club_East Fife', 'club_East Stirlingshire', 'club_Eastleigh', 'club_Ebbsfleet', 'club_Envigado F.C.', 'club_Everton', 'club_Exeter', 'club_FC Dallas', 'club_FC Edmonton', 'club_FC Halifax', 'club_FCV Dender', 'club_FH', 'club_Falkenberg', 'club_Falkir ...
# 2024-08-15 12:53:06,336 - INFO - Before filtering, data shape: (2183, 691)
# 2024-08-15 12:53:06,343 - INFO - After filtering goalkeepers, data shape: (1965, 691)
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   9.1s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   9.1s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   9.1s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   9.3s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   9.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   9.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=900; total time=   9.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   9.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   9.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=   9.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  12.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  16.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  16.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  16.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  16.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  16.6s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  13.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  13.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   4.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   4.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   4.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   4.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   4.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  13.4s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   5.0s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   5.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   5.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=900; total time=  13.9s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   5.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.8s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.2s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.0s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=  10.1s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=600; total time=   9.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  10.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   9.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=   9.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  11.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  10.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=100; total time=   1.4s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  22.0s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.1s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  22.2s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   5.9s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   5.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   5.9s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   5.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=10, n_estimators=400; total time=   5.4s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   6.7s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   6.5s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   6.5s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   6.6s
# [CV] END max_depth=30, min_samples_leaf=10, min_samples_split=5, n_estimators=600; total time=   7.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  21.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; total time=  22.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   8.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   8.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   8.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  20.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   8.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   8.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  21.2s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  19.5s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  20.3s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  20.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  12.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  12.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  12.4s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   6.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  11.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=700; total time=  11.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  28.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  29.2s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   6.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  28.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  27.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  29.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   6.2s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=500; total time=   6.2s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  13.0s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  12.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  13.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  11.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  13.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  11.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  11.5s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  13.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  13.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  14.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  14.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  14.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  14.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=800; total time=  14.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=  10.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=  10.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=  10.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=900; total time=  10.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=  10.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=   9.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=  10.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=  10.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   4.2s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   5.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   5.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   5.8s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   5.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=20, n_estimators=400; total time=   5.8s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=900; total time=  10.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   4.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   4.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   4.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=20, n_estimators=300; total time=   4.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=300; total time=   3.5s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  10.3s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  10.7s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  10.5s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  10.6s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=10, n_estimators=800; total time=  10.8s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   8.6s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   8.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   8.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   8.2s
# [CV] END max_depth=20, min_samples_leaf=10, min_samples_split=20, n_estimators=700; total time=   8.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  18.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  18.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   6.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  18.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   6.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   5.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  17.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   5.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=   5.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=800; total time=  18.3s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  11.8s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  11.7s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  11.8s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  12.3s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=600; total time=  11.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  11.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  12.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  12.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  11.3s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=2, n_estimators=800; total time=  11.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   7.8s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=  12.9s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=  12.7s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=  12.9s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=  12.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=2, n_estimators=900; total time=  12.9s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   6.9s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   7.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   3.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   6.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   7.0s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   3.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   3.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   5.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   5.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   5.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=2, n_estimators=500; total time=   5.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   9.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=   9.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  10.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   9.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   9.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   9.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   6.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   9.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   9.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   6.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=20, n_estimators=400; total time=   6.3s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  10.4s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  10.5s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   7.9s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   8.0s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   7.6s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  10.8s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  10.7s
# [CV] END max_depth=30, min_samples_leaf=5, min_samples_split=15, n_estimators=800; total time=  10.4s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   9.2s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   9.1s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  10.9s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  11.3s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  11.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   5.4s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   5.5s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=5, n_estimators=800; total time=  11.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   5.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   6.1s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   4.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   5.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   5.2s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=  11.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=  11.4s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   5.2s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=  11.1s
# [CV] END max_depth=50, min_samples_leaf=5, min_samples_split=5, n_estimators=600; total time=  11.6s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=15, n_estimators=300; total time=   5.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   5.4s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   5.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   5.0s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   3.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=10, n_estimators=300; total time=   3.8s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=  13.3s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=  13.5s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=  12.9s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=  13.6s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   6.7s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=15, n_estimators=900; total time=  13.4s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   8.3s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   8.5s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   8.2s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   8.7s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  13.0s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  12.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  12.8s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  13.2s
# [CV] END max_depth=10, min_samples_leaf=10, min_samples_split=10, n_estimators=800; total time=  11.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   9.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   9.9s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  17.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  17.8s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  17.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  17.5s
# [CV] END max_depth=10, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  17.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   9.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=2, n_estimators=600; total time=   9.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  12.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  11.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  11.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  11.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=15, n_estimators=700; total time=  11.4s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  12.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  11.6s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  11.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   6.8s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   6.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   6.8s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   6.6s
# [CV] END max_depth=40, min_samples_leaf=10, min_samples_split=20, n_estimators=500; total time=   6.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  11.9s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=5, n_estimators=900; total time=  12.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  13.7s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  13.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  14.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  21.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  21.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  21.4s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   1.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  21.6s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=900; total time=  21.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=20, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  15.4s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=1000; total time=  15.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=  10.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  16.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  16.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  16.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  16.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=600; total time=  16.4s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   9.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   9.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   3.0s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   2.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   2.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   2.7s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=20, n_estimators=200; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   9.6s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=15, n_estimators=600; total time=   9.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  10.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  10.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  10.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  10.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  10.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=  16.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=  16.8s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   7.5s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   7.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=  17.2s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   7.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   7.7s
# [CV] END max_depth=None, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   7.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=  17.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=900; total time=  17.9s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   4.6s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   4.5s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   4.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   4.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=  15.5s
# [CV] END max_depth=40, min_samples_leaf=5, min_samples_split=20, n_estimators=300; total time=   4.5s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=  15.7s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=  15.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=  15.6s
# [CV] END max_depth=40, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=700; total time=  14.9s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   5.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   5.6s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   5.8s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   6.3s
# [CV] END max_depth=50, min_samples_leaf=10, min_samples_split=5, n_estimators=400; total time=   6.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  20.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  21.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  20.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  17.0s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  16.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  16.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  20.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=900; total time=  21.1s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   6.5s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   6.9s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   6.6s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   6.8s
# [CV] END max_depth=None, min_samples_leaf=5, min_samples_split=5, n_estimators=400; total time=   6.6s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  13.4s
# [CV] END max_depth=40, min_samples_leaf=1, min_samples_split=20, n_estimators=500; total time=  13.6s
# [CV] END max_depth=20, min_samples_leaf=5, min_samples_split=20, n_estimators=900; total time=  14.7s
# ...
# /var/folders/fs/2pw0dc014ls93dt5yfjzx6w00000gn/T/ipykernel_59760/2337869566.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = 0
# /var/folders/fs/2pw0dc014ls93dt5yfjzx6w00000gn/T/ipykernel_59760/2337869566.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = 0
# /var/folders/fs/2pw0dc014ls93dt5yfjzx6w00000gn/T/ipykernel_59760/2337869566.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = 0
# /var/folders/fs/2pw0dc014ls93dt5yfjzx6w00000gn/T/ipykernel_59760/2337869566.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = 0
# /var/folders/fs/2pw0dc014ls93dt5yfjzx6w00000gn/T/ipykernel_59760/2337869566.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[col] = 0
# 2024-08-15 13:56:01,749 - INFO - Before filtering, data shape: (2630, 827)
# 2024-08-15 13:56:01,767 - INFO - After filtering goalkeepers, data shape: (2342, 827)
# 2024-08-15 13:56:02,079 - INFO - MSE Goals: 31
# 2024-08-15 13:56:02,080 - INFO - MSE Appearances: 1059
# 2024-08-15 13:56:02,080 - INFO - Accuracy Tier Quality: 0.7442356959863364
# /Applications/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Applications/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Applications/miniconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 2024-08-15 13:56:02,088 - INFO - Test Classification Report Tier Quality:
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99       510
#            2       0.00      0.00      0.00         1
#            3       0.96      0.99      0.97       511
#            4       0.98      0.97      0.97       398
#            5       0.99      0.75      0.85       339
#            6       0.15      0.98      0.26       101
#            7       0.00      0.00      0.00       482
#
#     accuracy                           0.74      2342
#    macro avg       0.58      0.67      0.58      2342
# weighted avg       0.74      0.74      0.73      2342
#
# 2024-08-15 13:56:02,138 - INFO - Feature importances for goals (as percentages): {'division': '2.17', 'division_tier': '0.97', 'birth_month': '1.03', 'birth_quarter': '0.73', 'age_(days)_on_1_july_2023': '36.10', 'age_(months)_on_1_july_2023': '13.28', 'age_(years)_on_1_july_2023': '0.75', 'height_(cm)': '1.02', 'weight_(kg)': '2.18', 'is_top_4_tier': '0.10', 'nation_of_birth_ANG': '0.00', 'nation_of_birth_AUT': '0.00', 'nation_of_birth_BER': '0.00', 'nation_of_birth_CAN': '0.00', 'nation_of_birth_CIV': '0.00', 'nation_of_birth_CMR': '0.00', 'nation_of_birth_COD': '0.00', 'nation_of_birth_COL': '0.00', 'nation_of_birth_ENG': '0.00', 'nation_of_birth_FRA': '0.00', 'nation_of_birth_GER': '0.00', 'nation_of_birth_GHA': '0.00', 'nation_of_birth_GNB': '0.00', 'nation_of_birth_IRL': '0.00', 'nation_of_birth_JAM': '0.00', 'nation_of_birth_MAS': '0.00', 'nation_of_birth_MON': '0.00', 'nation_of_birth_NED': '0.00', 'nation_of_birth_NGA': '0.00', 'nation_of_birth_POR': '0.00', 'nation_of_birth_RSA': '0.00', 'nation_of_birth_RUS': '0.00', 'nation_of_birth_SLE': '0.00', 'group_Defender': '2.05', 'group_Forward': '38.63', 'group_Goalkeeper': '0.00', 'group_Midfielder': '0.68', 'second_nationality_ALB': '0.00', 'second_nationality_ALG': '0.00', 'second_nationality_ANG': '0.00', 'second_nationality_ATG': '0.00', 'second_nationality_AUS': '0.00', 'second_nationality_BAN': '0.00', 'second_nationality_BDI': '0.00', 'second_nationality_BEL': '0.00', 'second_nationality_BER': '0.00', 'second_nationality_BRB': '0.00', 'second_nationality_CAN': '0.00', 'second_nationality_CIV': '0.00', 'second_nationality_CMR': '0.00', 'second_nationality_COD': '0.00', 'second_nationality_COL': '0.00', 'second_nationality_CPV': '0.00', 'second_nationality_CRO': '0.00', 'second_nationality_CYP': '0.00', 'second_nationality_CZE': '0.00', 'second_nationality_DMA': '0.00', 'second_nationality_ECU': '0.00', 'second_nationality_ERI': '0.00', 'second_nationality_ESP': '0.00', 'second_nationality_FIN': '0.00', 'second_nationality_FRA': '0.00', 'second_nationality_GAM': '0.00', 'second_nationality_GER': '0.00', 'second_nationality_GHA': '0.00', 'second_nationality_GNB': '0.00', 'second_nationality_GRE': '0.00', 'second_nationality_GRN': '0.00', 'second_nationality_GUI': '0.00', 'second_nationality_GUY': '0.00', 'second_nationality_HKG': '0.00', 'second_nationality_HUN': '0.00', 'second_nationality_IND': '0.00', 'second_nationality_IRL': '0.00', 'second_nationality_IRN': '0.00', 'second_nationality_ISR': '0.00', 'second_nationality_ITA': '0.00', 'second_nationality_JAM': '0.00', 'second_nationality_KEN': '0.00', 'second_nationality_LBR': '0.00', 'second_nationality_LCA': '0.00', 'second_nationality_LVA': '0.00', 'second_nationality_MAR': '0.00', 'second_nationality_MAS': '0.00', 'second_nationality_MLT': '0.00', 'second_nationality_MSR': '0.00', 'second_nationality_NCL': '0.00', 'second_nationality_NED': '0.00', 'second_nationality_NGA': '0.03', 'second_nationality_NIR': '0.00', 'second_nationality_NOR': '0.00', 'second_nationality_NZL': '0.00', 'second_nationality_PAK': '0.00', 'second_nationality_PHI': '0.00', 'second_nationality_POL': '0.00', 'second_nationality_POR': '0.00', 'second_nationality_RSA': '0.00', 'second_nationality_RUS': '0.00', 'second_nationality_SCO': '0.00', 'second_nationality_SGP': '0.00', 'second_nationality_SKN': '0.00', 'second_nationality_SLE': '0.00', 'second_nationality_SRB': '0.00', 'second_nationality_SWE': '0.00', 'second_nationality_TRI': '0.00', 'second_nationality_TUR': '0.00', 'second_nationality_UGA': '0.00', 'second_nationality_USA': '0.00', 'second_nationality_VEN': '0.00', 'second_nationality_WAL': '0.00', 'second_nationality_ZAM': '0.00', 'second_nationality_ZIM': '0.00', 'club_A. Baleares': '0.00', 'club_AA Gent': '0.00', 'club_AC Milan': '0.00', 'club_AC Oulu': '0.00', 'club_AEL': '0.00', 'club_AFC Croydon Athletic': '0.00', 'club_AFC Eskilstuna': '0.00', 'club_AFC Fylde': '0.00', 'club_AFC Wimbledon': '0.00', 'club_AS Roma': '0.00' ...
# 2024-08-15 13:56:02,139 - INFO - Feature importances for appearances (as percentages): {'division': '2.69', 'division_tier': '1.51', 'birth_month': '0.30', 'birth_quarter': '0.12', 'age_(days)_on_1_july_2023': '74.75', 'age_(months)_on_1_july_2023': '14.38', 'age_(years)_on_1_july_2023': '0.81', 'height_(cm)': '0.37', 'weight_(kg)': '0.57', 'is_top_4_tier': '0.36', 'nation_of_birth_ANG': '0.00', 'nation_of_birth_AUT': '0.00', 'nation_of_birth_BER': '0.00', 'nation_of_birth_CAN': '0.00', 'nation_of_birth_CIV': '0.00', 'nation_of_birth_CMR': '0.00', 'nation_of_birth_COD': '0.01', 'nation_of_birth_COL': '0.00', 'nation_of_birth_ENG': '0.01', 'nation_of_birth_FRA': '0.00', 'nation_of_birth_GER': '0.00', 'nation_of_birth_GHA': '0.00', 'nation_of_birth_GNB': '0.00', 'nation_of_birth_IRL': '0.00', 'nation_of_birth_JAM': '0.00', 'nation_of_birth_MAS': '0.00', 'nation_of_birth_MON': '0.00', 'nation_of_birth_NED': '0.00', 'nation_of_birth_NGA': '0.00', 'nation_of_birth_POR': '0.00', 'nation_of_birth_RSA': '0.00', 'nation_of_birth_RUS': '0.00', 'nation_of_birth_SLE': '0.00', 'group_Defender': '0.09', 'group_Forward': '0.10', 'group_Goalkeeper': '0.00', 'group_Midfielder': '0.04', 'second_nationality_ALB': '0.00', 'second_nationality_ALG': '0.00', 'second_nationality_ANG': '0.00', 'second_nationality_ATG': '0.00', 'second_nationality_AUS': '0.02', 'second_nationality_BAN': '0.00', 'second_nationality_BDI': '0.00', 'second_nationality_BEL': '0.01', 'second_nationality_BER': '0.00', 'second_nationality_BRB': '0.00', 'second_nationality_CAN': '0.00', 'second_nationality_CIV': '0.00', 'second_nationality_CMR': '0.00', 'second_nationality_COD': '0.01', 'second_nationality_COL': '0.00', 'second_nationality_CPV': '0.00', 'second_nationality_CRO': '0.00', 'second_nationality_CYP': '0.00', 'second_nationality_CZE': '0.00', 'second_nationality_DMA': '0.00', 'second_nationality_ECU': '0.00', 'second_nationality_ERI': '0.00', 'second_nationality_ESP': '0.02', 'second_nationality_FIN': '0.00', 'second_nationality_FRA': '0.00', 'second_nationality_GAM': '0.00', 'second_nationality_GER': '0.00', 'second_nationality_GHA': '0.00', 'second_nationality_GNB': '0.00', 'second_nationality_GRE': '0.00', 'second_nationality_GRN': '0.01', 'second_nationality_GUI': '0.00', 'second_nationality_GUY': '0.00', 'second_nationality_HKG': '0.00', 'second_nationality_HUN': '0.00', 'second_nationality_IND': '0.01', 'second_nationality_IRL': '0.13', 'second_nationality_IRN': '0.00', 'second_nationality_ISR': '0.00', 'second_nationality_ITA': '0.00', 'second_nationality_JAM': '0.03', 'second_nationality_KEN': '0.00', 'second_nationality_LBR': '0.00', 'second_nationality_LCA': '0.00', 'second_nationality_LVA': '0.00', 'second_nationality_MAR': '0.00', 'second_nationality_MAS': '0.00', 'second_nationality_MLT': '0.00', 'second_nationality_MSR': '0.00', 'second_nationality_NCL': '0.00', 'second_nationality_NED': '0.00', 'second_nationality_NGA': '0.02', 'second_nationality_NIR': '0.00', 'second_nationality_NOR': '0.00', 'second_nationality_NZL': '0.00', 'second_nationality_PAK': '0.02', 'second_nationality_PHI': '0.00', 'second_nationality_POL': '0.00', 'second_nationality_POR': '0.00', 'second_nationality_RSA': '0.01', 'second_nationality_RUS': '0.00', 'second_nationality_SCO': '0.03', 'second_nationality_SGP': '0.00', 'second_nationality_SKN': '0.00', 'second_nationality_SLE': '0.00', 'second_nationality_SRB': '0.00', 'second_nationality_SWE': '0.00', 'second_nationality_TRI': '0.01', 'second_nationality_TUR': '0.00', 'second_nationality_UGA': '0.00', 'second_nationality_USA': '0.02', 'second_nationality_VEN': '0.00', 'second_nationality_WAL': '0.00', 'second_nationality_ZAM': '0.00', 'second_nationality_ZIM': '0.00', 'club_A. Baleares': '0.00', 'club_AA Gent': '0.00', 'club_AC Milan': '0.00', 'club_AC Oulu': '0.02', 'club_AEL': '0.00', 'club_AFC Croydon Athletic': '0.00', 'club_AFC Eskilstuna': '0.01', 'club_AFC Fylde': '0.01', 'club_AFC Wimbledon': '0.00', 'club_AS Roma': ' ...
# 2024-08-15 13:56:02,139 - INFO - Feature importances for tier quality (as percentages): {'division': '23.54', 'division_tier': '20.51', 'birth_month': '0.77', 'birth_quarter': '0.45', 'age_(days)_on_1_july_2023': '1.40', 'age_(months)_on_1_july_2023': '1.34', 'age_(years)_on_1_july_2023': '0.90', 'height_(cm)': '0.79', 'weight_(kg)': '1.04', 'is_top_4_tier': '17.20', 'nation_of_birth_ANG': '0.00', 'nation_of_birth_AUT': '0.01', 'nation_of_birth_BER': '0.00', 'nation_of_birth_CAN': '0.04', 'nation_of_birth_CIV': '0.00', 'nation_of_birth_CMR': '0.00', 'nation_of_birth_COD': '0.01', 'nation_of_birth_COL': '0.00', 'nation_of_birth_ENG': '0.08', 'nation_of_birth_FRA': '0.00', 'nation_of_birth_GER': '0.00', 'nation_of_birth_GHA': '0.01', 'nation_of_birth_GNB': '0.02', 'nation_of_birth_IRL': '0.00', 'nation_of_birth_JAM': '0.01', 'nation_of_birth_MAS': '0.00', 'nation_of_birth_MON': '0.00', 'nation_of_birth_NED': '0.00', 'nation_of_birth_NGA': '0.00', 'nation_of_birth_POR': '0.00', 'nation_of_birth_RSA': '0.01', 'nation_of_birth_RUS': '0.00', 'nation_of_birth_SLE': '0.01', 'group_Defender': '0.24', 'group_Forward': '0.20', 'group_Goalkeeper': '0.00', 'group_Midfielder': '0.22', 'second_nationality_ALB': '0.00', 'second_nationality_ALG': '0.00', 'second_nationality_ANG': '0.03', 'second_nationality_ATG': '0.00', 'second_nationality_AUS': '0.02', 'second_nationality_BAN': '0.00', 'second_nationality_BDI': '0.00', 'second_nationality_BEL': '0.01', 'second_nationality_BER': '0.00', 'second_nationality_BRB': '0.03', 'second_nationality_CAN': '0.07', 'second_nationality_CIV': '0.05', 'second_nationality_CMR': '0.05', 'second_nationality_COD': '0.08', 'second_nationality_COL': '0.00', 'second_nationality_CPV': '0.00', 'second_nationality_CRO': '0.00', 'second_nationality_CYP': '0.05', 'second_nationality_CZE': '0.00', 'second_nationality_DMA': '0.00', 'second_nationality_ECU': '0.02', 'second_nationality_ERI': '0.00', 'second_nationality_ESP': '0.04', 'second_nationality_FIN': '0.02', 'second_nationality_FRA': '0.00', 'second_nationality_GAM': '0.01', 'second_nationality_GER': '0.00', 'second_nationality_GHA': '0.11', 'second_nationality_GNB': '0.00', 'second_nationality_GRE': '0.01', 'second_nationality_GRN': '0.03', 'second_nationality_GUI': '0.00', 'second_nationality_GUY': '0.04', 'second_nationality_HKG': '0.02', 'second_nationality_HUN': '0.02', 'second_nationality_IND': '0.08', 'second_nationality_IRL': '0.12', 'second_nationality_IRN': '0.00', 'second_nationality_ISR': '0.00', 'second_nationality_ITA': '0.01', 'second_nationality_JAM': '0.14', 'second_nationality_KEN': '0.04', 'second_nationality_LBR': '0.00', 'second_nationality_LCA': '0.04', 'second_nationality_LVA': '0.00', 'second_nationality_MAR': '0.00', 'second_nationality_MAS': '0.00', 'second_nationality_MLT': '0.01', 'second_nationality_MSR': '0.01', 'second_nationality_NCL': '0.00', 'second_nationality_NED': '0.08', 'second_nationality_NGA': '0.19', 'second_nationality_NIR': '0.03', 'second_nationality_NOR': '0.00', 'second_nationality_NZL': '0.01', 'second_nationality_PAK': '0.02', 'second_nationality_PHI': '0.03', 'second_nationality_POL': '0.01', 'second_nationality_POR': '0.03', 'second_nationality_RSA': '0.01', 'second_nationality_RUS': '0.01', 'second_nationality_SCO': '0.09', 'second_nationality_SGP': '0.00', 'second_nationality_SKN': '0.00', 'second_nationality_SLE': '0.01', 'second_nationality_SRB': '0.00', 'second_nationality_SWE': '0.00', 'second_nationality_TRI': '0.01', 'second_nationality_TUR': '0.00', 'second_nationality_UGA': '0.03', 'second_nationality_USA': '0.09', 'second_nationality_VEN': '0.00', 'second_nationality_WAL': '0.01', 'second_nationality_ZAM': '0.00', 'second_nationality_ZIM': '0.01', 'club_A. Baleares': '0.00', 'club_AA Gent': '0.03', 'club_AC Milan': '0.07', 'club_AC Oulu': '0.00', 'club_AEL': '0.03', 'club_AFC Croydon Athletic': '0.01', 'club_AFC Eskilstuna': '0.06', 'club_AFC Fylde': '0.10', 'club_AFC Wimbledon': '0.25', 'club_AS Roma': ...
# 2024-08-15 13:56:02,162 - INFO - Predictions have been saved to 'predictions_2024_youth.csv'.
